# %% [markdown]
# # 대구 태풍 데이터
# > ###### Made by SSJ
#
# #### Period
# - 2022.05.17
#
# #### 사용 데이터
# 태풍 목록 데이터 : https://data.kma.go.kr/data/typhoonData/typList.do?pgmNo=688
# 태풍 예보 데이터 : https://data.kma.go.kr/data/typhoonData/typInfoTYList.do?pgmNo=689
#
# <br>
# <details><summary>위도별 경도의 길이표 (예시로 실제로는 사용하지 않은 표)</summary>
#
# |위도(˚)|위도 1도의 길이(㎞)|경도 1도의 길이(㎞)|
# |---|---|---|
# |0|110.569|111.322|
# |5|110.578|110.902|
# |10|110.603|109.643|
# |15|110.644|117.553|
# |20|110.701|114.650|
# |25|110.770|100.953|
# |30|110.850|96.490|
# |<b>*35*</b>|<b>*110.941*</b>|<b>*91.290*</b>|
# |40|111.034|85.397|
# |45|111.132|78.850|
# |50|111.230|71.700|
# |55|111.327|63.997|
# |60|111.415|55.803|
# |65|111.497|47.178|
# |70|111.567|38.188|
# |75|111.625|28.904|
# |80|111.666|19.394|
# |85|111.692|9.735|
# |90|111.700|0.000|
# </details>

# %% [markdown]
# ## 0. 필요한 패키지 불러오기

# %%
from haversine import haversine
import pandas as pd
import glob

# %% [markdown]
# # 1. 파일 읽어오기

# %%
# glob을 통해 폴더내에 존재하는 csv의 파일명을 all_files에 저장
all_files = glob.glob("./dataset/cyclone/*.csv")

dfs = []
for i in all_files:
    # 각각의 파일명의 데이터 읽어오기
    df = pd.read_csv(i, encoding="cp949")

    # 파일명에 적혀있는 태풍의 이름 추출
    name = i.replace('./dataset/cyclone\FCT_태풍정보_','').replace('.csv','').replace(' (2)','')
    
    # 24,28,72시간 뒤의 예상 데이터 삭제
    df = df[df['Unnamed: 1'] == 0]
    
    # 태풍명을 DF에 추가
    df['name'] = name
    dfs.append(df)

# 불러온 파일들을 전부 합치기
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#                      일시  Unnamed: 1  위도(N)  경도(E)  중심기압  초속(m/s)  시속(km/h)  \
# 0     2015년 08월 15일 03시           0   13.0  148.2  1000       18        65
# 1     2015년 08월 15일 09시           0   13.0  147.0   990       24        86
# 2     2015년 08월 15일 15시           0   13.5  146.3   990       24        86
# 3     2015년 08월 15일 21시           0   14.0  145.7   990       24        86
# 4     2015년 08월 16일 03시           0   14.1  144.9   985       27        97
# ...                 ...         ...    ...    ...   ...      ...       ...
# 1584  2014년 08월 10일 09시           0   34.2  134.3   970       36       130
# 1585  2014년 08월 10일 15시           0   36.3  135.7   975       34       122
# 1586  2014년 08월 10일 21시           0   38.9  136.7   980       31       112
# 1587  2014년 08월 11일 03시           0   41.2  137.0   985       27        97
# 1588  2014년 08월 11일 09시           0   44.3  137.0   980       -1        -4
#
#       강풍반경(km)[예외반경] 강도  크기 진행방향  이동속도(km/h)  70% 확률 반경(km) name
# 0                150  약  소형  서북서        16.0            0.0   고니
# 1                150  약  소형    서        22.0            0.0   고니
# 2                170  약  소형   북서        16.0            0.0   고니
# 3                200  약  소형   북서        14.0            0.0   고니
# 4                220  중  소형    서        15.0            0.0   고니
# ...              ... ..  ..  ...         ...            ...  ...
# 1584             300  강  중형   북동        27.0            0.0   할롱
# 1585             300  강  중형  북북동        44.0            0.0   할롱
# 1586             280  중  소형  북북동        50.0            0.0   할롱
# 1587             200  중  소형    북        43.0            0.0   할롱
# 1588               0  -   -    북        57.0            0.0   할롱
#
# [1589 rows x 14 columns]

# %% [markdown]
# ## 2. 태풍의 위치 계산

# %%
# 대구 위도 경도
daegu = (35.85, 128.56)

index = []
for i in range(1589):
    cyclone = (df.loc[i,'위도(N)'], df.loc[i,'경도(E)'])

    # 대구가 강풍반경 내에 있는지를 확인
    # haversine은 위도, 경도 데이터에서 km거리를 계산해주는 함수
    if haversine(daegu, cyclone) < df.loc[i,'강풍반경(km)[예외반경]']:
        index.append(i)

# 강풍반경 내에 있는 index만 저장
df1 = df.loc[index,:]
df1
# Out:
#                      일시  Unnamed: 1  위도(N)  경도(E)  중심기압  초속(m/s)  시속(km/h)  \
# 44    2015년 08월 25일 09시           0   33.9  130.7   960       39       140
# 45    2015년 08월 25일 12시           0   34.9  131.0   970       35       126
# 46    2015년 08월 25일 15시           0   35.9  131.2   975       32       115
# 323   2013년 10월 08일 21시           0   34.5  129.4   980       31       112
# 404   2012년 08월 30일 15시           0   35.7  127.8   995       20        72
# 424   2010년 08월 11일 06시           0   34.6  127.4   990       24        86
# 425   2010년 08월 11일 09시           0   34.9  128.0   990       24        86
# 426   2010년 08월 11일 12시           0   35.3  128.8   990       24        86
# 427   2010년 08월 11일 15시           0   35.6  129.8   990       24        86
# 537   2019년 09월 07일 06시           0   34.7  124.9   960       39       140
# 538   2019년 09월 07일 09시           0   35.6  125.0   965       37       133
# 539   2019년 09월 07일 12시           0   36.7  125.3   965       37       133
# 570   2020년 09월 02일 21시           0   33.1  127.9   945       45       162
# 571   2020년 09월 03일 00시           0   34.0  128.4   950       43       155
# 572   2020년 09월 03일 03시           0   35.4  128.9   960       39       140
# 573   2020년 09월 03일 06시           0   37.3  129.1   960       39       140
# 752   2019년 10월 03일 00시           0   34.9  127.2   990       20        72
# 753   2019년 10월 03일 03시           0   35.7  128.2   992       19        68
# 818   2012년 08월 28일 03시           0   32.9  125.4   960       40       144
# 819   2012년 08월 28일 06시           0   34.0  125.6   960       40       144
# 820   2012년 08월 28일 09시           0   35.4  125.6   960       40       144
# 821   2012년 08월 28일 12시           0   36.5  125.6   960       40       144
# 822   2012년 08월 28일 15시           0   37.7  125.6   965       38       137
# 899   2018년 07월 03일 18시           0   33.9  129.1   980       27        97
# 573              300     강  중형    북        70.0            NaN   마이삭
# 752              200     -  소형  동북동        33.0            NaN    미탁
# 753              170     -  소형   북동        42.0            NaN    미탁
# 818              450     강  중형    북        26.0            0.0   볼라벤
# 819              450     강  중형    북        41.0            0.0   볼라벤
# 820              430     강  중형    북        52.0            0.0   볼라벤
# 821              430     강  중형    북        41.0            0.0   볼라벤
# 822              400     강  중형    북        44.0            0.0   볼라벤
# 899              250     중  소형  북북동        25.0            NaN  쁘라삐룬
# 900              200     중  소형   북동        24.0            NaN  쁘라삐룬
# 934              380     강  중형    북        34.0            0.0    산바
# 935              380     강  중형  북북동        34.0            0.0    산바
# 936              380     강  중형    북        37.0            0.0    산바
# 937              350     중  중형    북        41.0            0.0    산바
# 938              270     약  소형  북북동        37.0            0.0    산바
# 977              290     중  소형  동북동        12.0            NaN    솔릭
# 978              270     중  소형   북동        27.0            NaN    솔릭
# 979              230     약  소형   북동        31.0            NaN    솔릭
# 980              210     약  소형  북북동        32.0            NaN    솔릭
# 1001             110     -  소형   북동        65.0            NaN  오마이스
# 1002             110     -  소형   북동        53.0            NaN  오마이스
# 1013             180     -   -  북북동        55.0            NaN    장미
# 1087             280     강  소형   북동        40.0            0.0    차바
# 1088             260     강  소형   북동        45.0            0.0    차바
# 1089             230     중  소형  동북동        43.0            0.0    차바
# 1090             220     중  소형  동북동        57.0            0.0    차바
# 1251             340     중  중형   북동        49.0            NaN   콩레이
# 1252             330     중  중형   북동        41.0            NaN   콩레이
# 1253             280     중  소형   북동        53.0            NaN   콩레이
# 1254             230     중  소형   북동        65.0            NaN   콩레이
# 1343             330     강  중형   북동        39.0            NaN    타파
# 1344             290     중  소형   북동        57.0            NaN    타파
# 1345             250     중  소형  동북동        47.0            NaN    타파
# 1476             400     강  중형    북        37.0            NaN   하이선
# 1477             380     강  중형    북        41.0            NaN   하이선
# 1478             380     강  중형    북        48.0            NaN   하이선
# 1479             350     중  중형    북        59.0            NaN   하이선
# 1480             330     중  중형    북        64.0            NaN   하이선

# %% [markdown]
# ## 3. 날짜에 대한 컬럼 정리

# %%
# 연도 컬럼 생성
temp = df1['일시'].str.split('년 ')
df1['년'] = temp.str[0]

# 월 컬럼 생성
temp = temp.str[1].str.split('월 ')
df1['월'] = temp.str[0]

# 일 컬럼 생성
temp = temp.str[1].str.split('일 ')
df1['일'] = temp.str[0]

# 시각 걸럼 생성
df1['시'] = temp.str[1].str.replace('시','')

# %% [markdown]
# ## 4. 니 마음속에 저★장

# %%
# 실제로 필요한 컬럼만 저장
df_final = df1.loc[:,['name','년','월','일','시','위도(N)','경도(E)','중심기압','초속(m/s)','시속(km/h)','강풍반경(km)[예외반경]','강도','크기','진행방향','이동속도(km/h)']]
df_final.to_csv('./output/대구 태풍.csv', index=False, encoding='cp949')
