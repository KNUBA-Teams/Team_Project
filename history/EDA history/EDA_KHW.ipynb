# %% [markdown]
# # ※ 필요한 패키지 및 데이터 불러오기

# %%
# 모듈 선언
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import platform
import matplotlib

# %% [markdown]
# ## 2. 인구밀도가 높은 지역은 상대적으로 열지수가 높다.
# - made by KHW

# %% [markdown]
# ### 0. 전처리

# %% [markdown]
# **1. 인구밀도 데이터**

# %%
df_dens = pd.read_csv('../../output/Daegu_density.csv', index_col=0)

df_dens
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 0       가창면  2010     10   9002   111.17     80.975083
# 1       가창면  2010     11   8969   111.17     80.678241
# 2       가창면  2010     12   8936   111.17     80.381398
# 3       가창면  2011      1   8892   111.17     79.985608
# 4       가창면  2011      2   8731   111.17     78.537375
# ...     ...   ...    ...    ...      ...           ...
# 19400  효목2동  2021     12  13167     0.72  18287.500000
# 19401  효목2동  2022      1  13121     0.72  18223.611111
# 19402  효목2동  2022      2  13098     0.72  18191.666667
# 19403  효목2동  2022      3  13070     0.72  18152.777778
# 19404  효목2동  2022      4  13043     0.72  18115.277778
#
# [19405 rows x 6 columns]

# %% [markdown]
# **2. 기상 데이터**

# %%
df_weather = pd.read_csv('../../output/daegu_final.csv')

df_weather
# Out:
#           year  month  day  hour             datetime  temp  rainfall  \
# 0         2010      6    1     0  2010-06-01 00:00:00  16.5       0.0
# 1         2010      6    1     1  2010-06-01 01:00:00  18.1       0.0
# 2         2010      6    1     2  2010-06-01 02:00:00  19.7       0.0
# 3         2010      6    1     3  2010-06-01 03:00:00  20.8       0.0
# 4         2010      6    1     4  2010-06-01 04:00:00  22.2       0.0
# ...        ...    ...  ...   ...                  ...   ...       ...
# 14831611  2022      4   30    19  2022-04-30 19:00:00  10.7       0.0
# 14831612  2022      4   30    20  2022-04-30 20:00:00  11.0       0.0
# 14831613  2022      4   30    21  2022-04-30 21:00:00  11.9       0.0
# 14831614  2022      4   30    22  2022-04-30 22:00:00  13.4       0.0
# 14831615  2022      4   30    23  2022-04-30 23:00:00  15.1       0.0
#
#           lightning  humidity  wind_speed  wind_direction  condition region  \
# 0                -1      53.0         NaN             NaN          1    동인동
# 1                -1      49.0         NaN             NaN          1    동인동
# 2                -1      46.0         NaN             NaN          1    동인동
# 3                -1      41.0         NaN             NaN          1    동인동
# 4                -1      36.0         NaN             NaN          2    동인동
# ...             ...       ...         ...             ...        ...    ...
# 14831611         -1      71.0         2.1           335.0         -1    구지면
# 14831612         -1      65.0         2.2           339.0         -1    구지면
# 14831613         -1      61.0         2.2           338.0         -1    구지면
# 14831614         -1      53.0         2.0           351.0         -1    구지면
# 14831615         -1      41.0         2.1             5.0         -1    구지면
#
#                  HI        DI
# 0         15.589444  60.74355
# 1         17.245000  62.73431
# 2         18.926667  64.65038
# 3         20.006111  65.72772
# 4         21.415556  67.04608
# ...             ...       ...
# 14831611   9.679444  52.33503
# 14831612   9.852778  52.99350
# 14831613  10.738333  54.40241
# 14831614  12.179444  56.60598
# 14831615  13.736111  58.79709
#
# [14831616 rows x 15 columns]

# %% [markdown]
# **2-1. 사용할 column만 추출**

# %%
df_HI = df_weather[['region', 'year', 'month', 'HI']]

df_HI
# Out:
#          region  year  month         HI
# 0           동인동  2010      6  15.589444
# 1           동인동  2010      6  17.245000
# 2           동인동  2010      6  18.926667
# 3           동인동  2010      6  20.006111
# 4           동인동  2010      6  21.415556
# ...         ...   ...    ...        ...
# 14831611    구지면  2022      4   9.679444
# 14831612    구지면  2022      4   9.852778
# 14831613    구지면  2022      4  10.738333
# 14831614    구지면  2022      4  12.179444
# 14831615    구지면  2022      4  13.736111
#
# [14831616 rows x 4 columns]

# %% [markdown]
# **2-2. 파일 기간 통합을 위해 2010년 10월 이전의 row 삭제**

# %%
df_HI.drop(df_HI[(df_HI['year'] == 2010) & (df_HI['month'] < 10)].index, inplace=True)

df_HI
# Out:
# C:\Users\trap1\AppData\Local\Temp\ipykernel_2164\486867846.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_HI.drop(df_HI[(df_HI['year'] == 2010) & (df_HI['month'] < 10)].index, inplace=True)
#          region  year  month         HI
# 2928        동인동  2010     10  14.079444
# 2929        동인동  2010     10  16.930000
# 2930        동인동  2010     10  18.339444
# 2931        동인동  2010     10  20.241111
# 2932        동인동  2010     10  21.603889
# ...         ...   ...    ...        ...
# 14831611    구지면  2022      4   9.679444
# 14831612    구지면  2022      4   9.852778
# 14831613    구지면  2022      4  10.738333
# 14831614    구지면  2022      4  12.179444
# 14831615    구지면  2022      4  13.736111
#
# [14415840 rows x 4 columns]

# %% [markdown]
# **2-3. 달별로 중복된 row를 region명으로 평균값 통합**

# %%
df_HI = df_HI.groupby(["region","year","month"]).mean().reset_index()

df_HI
# Out:
#       region  year  month         HI
# 0        가창면  2010     10  14.002856
# 1        가창면  2010     11   5.548623
# 2        가창면  2010     12  -0.149288
# 3        가창면  2011      1  -4.443683
# 4        가창면  2011      2   1.583097
# ...      ...   ...    ...        ...
# 19733   효목2동  2021     12   2.357998
# 19734   효목2동  2022      1   0.478563
# 19735   효목2동  2022      2   1.146696
# 19736   효목2동  2022      3   8.569070
# 19737   효목2동  2022      4  15.072408
#
# [19738 rows x 4 columns]

# %% [markdown]
# **3. 안 겹치는 행정구역명이 있는지 확인하기 위해 outer join**

# %%
df_join = pd.merge(df_dens, df_HI, left_on=['행정구역','year','month'], right_on = ['region','year','month'], how='outer')

df_join
# Out:
#       행정구역  year  month   count  면적(km²)       인구밀도 region         HI
# 0      가창면  2010     10  9002.0   111.17  80.975083    가창면  14.002856
# 1      가창면  2010     11  8969.0   111.17  80.678241    가창면   5.548623
# 2      가창면  2010     12  8936.0   111.17  80.381398    가창면  -0.149288
# 3      가창면  2011      1  8892.0   111.17  79.985608    가창면  -4.443683
# 4      가창면  2011      2  8731.0   111.17  78.537375    가창면   1.583097
# ...    ...   ...    ...     ...      ...        ...    ...        ...
# 19749  NaN  2019      8     NaN      NaN        NaN    혁신동  29.633990
# 19750  NaN  2019      9     NaN      NaN        NaN    혁신동  23.240009
# 19751  NaN  2019     10     NaN      NaN        NaN    혁신동  16.214514
# 19752  NaN  2019     11     NaN      NaN        NaN    혁신동   8.793609
# 19753  NaN  2019     12     NaN      NaN        NaN    혁신동   2.689205
#
# [19754 rows x 8 columns]

# %% [markdown]
# **4. join한 파일의 null 값 확인**

# %%
df_join[df_join['행정구역'].isnull()]
# Out:
#       행정구역  year  month  count  면적(km²)  인구밀도  region         HI
# 19405  NaN  2021      1    NaN      NaN   NaN  안심3.4동   0.003336
# 19406  NaN  2021      2    NaN      NaN   NaN  안심3.4동   3.876480
# 19407  NaN  2021      3    NaN      NaN   NaN  안심3.4동   8.844997
# 19408  NaN  2021      4    NaN      NaN   NaN  안심3.4동  12.973838
# 19409  NaN  2021      5    NaN      NaN   NaN  안심3.4동  17.479504
# ...    ...   ...    ...    ...      ...   ...     ...        ...
# 19749  NaN  2019      8    NaN      NaN   NaN     혁신동  29.633990
# 19750  NaN  2019      9    NaN      NaN   NaN     혁신동  23.240009
# 19751  NaN  2019     10    NaN      NaN   NaN     혁신동  16.214514
# 19752  NaN  2019     11    NaN      NaN   NaN     혁신동   8.793609
# 19753  NaN  2019     12    NaN      NaN   NaN     혁신동   2.689205
#
# [349 rows x 8 columns]

# %%
df_join[df_join['인구밀도'].isnull()]
# Out:
#       행정구역  year  month  count  면적(km²)  인구밀도  region         HI
# 19405  NaN  2021      1    NaN      NaN   NaN  안심3.4동   0.003336
# 19406  NaN  2021      2    NaN      NaN   NaN  안심3.4동   3.876480
# 19407  NaN  2021      3    NaN      NaN   NaN  안심3.4동   8.844997
# 19408  NaN  2021      4    NaN      NaN   NaN  안심3.4동  12.973838
# 19409  NaN  2021      5    NaN      NaN   NaN  안심3.4동  17.479504
# ...    ...   ...    ...    ...      ...   ...     ...        ...
# 19749  NaN  2019      8    NaN      NaN   NaN     혁신동  29.633990
# 19750  NaN  2019      9    NaN      NaN   NaN     혁신동  23.240009
# 19751  NaN  2019     10    NaN      NaN   NaN     혁신동  16.214514
# 19752  NaN  2019     11    NaN      NaN   NaN     혁신동   8.793609
# 19753  NaN  2019     12    NaN      NaN   NaN     혁신동   2.689205
#
# [349 rows x 8 columns]

# %%
df_join[df_join['인구밀도'] == 0]
# Out:
#          행정구역  year  month  count  면적(km²)  인구밀도  region         HI
# 13878  안심3.4동  2020      7    0.0    25.12   0.0  안심3.4동  23.572870
# 13879  안심3.4동  2020      8    0.0    25.12   0.0  안심3.4동  31.253171
# 13880  안심3.4동  2020      9    0.0    25.12   0.0  안심3.4동  21.014922
# 13881  안심3.4동  2020     10    0.0    25.12   0.0  안심3.4동  14.181374
# 13882  안심3.4동  2020     11    0.0    25.12   0.0  안심3.4동   8.109772
# 13883  안심3.4동  2020     12    0.0    25.12   0.0  안심3.4동   0.796650
# 13884    안심3동  2020      1    0.0     6.10   0.0    안심3동   3.071850
# 13885    안심3동  2020      2    0.0     6.10   0.0    안심3동   4.169255
# 13886    안심3동  2020      3    0.0     6.10   0.0    안심3동   8.383952
# 13887    안심3동  2020      4    0.0     6.10   0.0    안심3동  11.411884
# 13888    안심3동  2020      5    0.0     6.10   0.0    안심3동  19.138936
# 13889    안심3동  2020      6    0.0     6.10   0.0    안심3동  24.717954
# 13912    안심4동  2020      1    0.0     2.53   0.0    안심4동   3.071850
# 13913    안심4동  2020      2    0.0     2.53   0.0    안심4동   4.169255
# 13914    안심4동  2020      3    0.0     2.53   0.0    안심4동   8.383952
# 13915    안심4동  2020      4    0.0     2.53   0.0    안심4동  11.411884
# 13916    안심4동  2020      5    0.0     2.53   0.0    안심4동  19.138936
# 13917    안심4동  2020      6    0.0     2.53   0.0    안심4동  24.717954
# 14913     유천동  2021      1    0.0     1.25   0.0     NaN        NaN
# 14914     유천동  2021      2    0.0     1.25   0.0     NaN        NaN
# 14915     유천동  2021      3    0.0     1.25   0.0     NaN        NaN
# 14916     유천동  2021      4    0.0     1.25   0.0     NaN        NaN
# 14917     유천동  2021      5    0.0     1.25   0.0     NaN        NaN
# 14918     유천동  2021      6    0.0     1.25   0.0     NaN        NaN
# 14919     유천동  2021      7    0.0     1.25   0.0     NaN        NaN
# 14920     유천동  2021      8    0.0     1.25   0.0     NaN        NaN
# 14921     유천동  2021      9    0.0     1.25   0.0     NaN        NaN
# 14922     유천동  2021     10    0.0     1.25   0.0     NaN        NaN
# 18543     혁신동  2020      1    0.0    16.42   0.0     혁신동   3.071850
# 18544     혁신동  2020      2    0.0    16.42   0.0     혁신동   4.169255
# 18545     혁신동  2020      3    0.0    16.42   0.0     혁신동   8.383952
# 18546     혁신동  2020      4    0.0    16.42   0.0     혁신동  11.411884
# 18547     혁신동  2020      5    0.0    16.42   0.0     혁신동  19.138936
# 18548     혁신동  2020      6    0.0    16.42   0.0     혁신동  24.717954

# %% [markdown]
# * **JOIN한 테이블들의 unique값 점검**

# %%
set(df_dens['행정구역'].unique()) - set(df_HI['region'].unique())
# Out:
# {'유천동'}

# %%
# 
set(df_HI['region'].unique()) - set(df_dens['행정구역'].unique())
# Out:
# set()

# %% [markdown]
# **4-1. 안심3.4동, 안심3동, 안심4동, 혁신동 데이터 확인**
# * 2020년을 6월을 기준으로 안심3.4동과 안심3동, 안심4동, 혁신동이 분리되어 있다.
#
# 조사
# * 2020년 7월 6일 안심3·4동을 안심3동, 안심4동, 혁신동으로 분동
# 출처 : https://ko.wikipedia.org/wiki/%EC%95%88%EC%8B%AC%EB%8F%99

# %%
df_dens[(df_dens['행정구역']=='안심3.4동') & (df_dens['year']==2020)]
# Out:
#          행정구역  year  month  count  면적(km²)         인구밀도
# 13872  안심3.4동  2020      1  69135    25.12  2752.189490
# 13873  안심3.4동  2020      2  69040    25.12  2748.407643
# 13874  안심3.4동  2020      3  69150    25.12  2752.786624
# 13875  안심3.4동  2020      4  69421    25.12  2763.574841
# 13876  안심3.4동  2020      5  69537    25.12  2768.192675
# 13877  안심3.4동  2020      6  69573    25.12  2769.625796
# 13878  안심3.4동  2020      7      0    25.12     0.000000
# 13879  안심3.4동  2020      8      0    25.12     0.000000
# 13880  안심3.4동  2020      9      0    25.12     0.000000
# 13881  안심3.4동  2020     10      0    25.12     0.000000
# 13882  안심3.4동  2020     11      0    25.12     0.000000
# 13883  안심3.4동  2020     12      0    25.12     0.000000

# %%
ansim_list = ['안심3동', '안심4동', '혁신동']

df_dens[(df_dens['행정구역'].isin(ansim_list)) & (df_dens['year']==2020)]
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 13884  안심3동  2020      1      0     6.10      0.000000
# 13885  안심3동  2020      2      0     6.10      0.000000
# 13886  안심3동  2020      3      0     6.10      0.000000
# 13887  안심3동  2020      4      0     6.10      0.000000
# 13888  안심3동  2020      5      0     6.10      0.000000
# 13889  안심3동  2020      6      0     6.10      0.000000
# 13890  안심3동  2020      7  21450     6.10   3516.393443
# 13891  안심3동  2020      8  21443     6.10   3515.245902
# 13892  안심3동  2020      9  21388     6.10   3506.229508
# 13893  안심3동  2020     10  21379     6.10   3504.754098
# 13894  안심3동  2020     11  21380     6.10   3504.918033
# 13895  안심3동  2020     12  21337     6.10   3497.868852
# 13912  안심4동  2020      1      0     2.53      0.000000
# 13913  안심4동  2020      2      0     2.53      0.000000
# 13914  안심4동  2020      3      0     2.53      0.000000
# 13915  안심4동  2020      4      0     2.53      0.000000
# 13916  안심4동  2020      5      0     2.53      0.000000
# 13917  안심4동  2020      6      0     2.53      0.000000
# 13918  안심4동  2020      7  29515     2.53  11666.007905
# 13919  안심4동  2020      8  29515     2.53  11666.007905
# 13920  안심4동  2020      9  29453     2.53  11641.501976
# 13921  안심4동  2020     10  29409     2.53  11624.110672
# 13922  안심4동  2020     11  29367     2.53  11607.509881
# 13923  안심4동  2020     12  29277     2.53  11571.936759
# 18543   혁신동  2020      1      0    16.42      0.000000
# 18544   혁신동  2020      2      0    16.42      0.000000
# 18545   혁신동  2020      3      0    16.42      0.000000
# 18546   혁신동  2020      4      0    16.42      0.000000
# 18547   혁신동  2020      5      0    16.42      0.000000
# 18548   혁신동  2020      6      0    16.42      0.000000
# 18549   혁신동  2020      7  18779    16.42   1143.666261
# 18550   혁신동  2020      8  18845    16.42   1147.685749
# 18551   혁신동  2020      9  18859    16.42   1148.538368
# 18552   혁신동  2020     10  18846    16.42   1147.746650
# 18553   혁신동  2020     11  18821    16.42   1146.224117
# 18554   혁신동  2020     12  18863    16.42   1148.781973

# %% [markdown]
# * **안심 3.4동은 2020년 7월부터 2022년까지의 값을 제거**

# %%
df_dens.drop(df_dens.loc[(df_dens['행정구역'] == '안심3.4동') & (df_dens['year'] == 2020) & (df_dens['month'] > 6)].index, inplace=True)

df_dens.drop(df_dens.loc[(df_dens['행정구역'] == '안심3.4동') & (df_dens['year'] > 2020)].index, inplace=True)

# %%
df_HI.drop(df_HI.loc[(df_HI['region'] == '안심3.4동') & (df_HI['year'] == 2020) & (df_HI['month'] > 6)].index, inplace=True)

df_HI.drop(df_HI.loc[(df_HI['region'] == '안심3.4동') & (df_HI['year'] > 2020)].index, inplace=True)

# %% [markdown]
# * **안심3동, 안심4동, 혁신동은 2010년부터 2020년 6월까지의 값을 제거**

# %%
df_dens.drop(df_dens.loc[(df_dens['행정구역'].isin(ansim_list)) & (df_dens['year'] == 2020) & (df_dens['month'] < 7)].index, inplace=True)

df_dens.drop(df_dens.loc[(df_dens['행정구역'].isin(ansim_list)) & (df_dens['year'] < 2020)].index, inplace=True)

# %%
df_HI.drop(df_HI.loc[(df_HI['region'].isin(ansim_list)) & (df_HI['year'] == 2020) & (df_HI['month'] < 7)].index, inplace=True)

df_HI.drop(df_HI.loc[(df_HI['region'].isin(ansim_list)) & (df_HI['year'] < 2020)].index, inplace=True)

# %% [markdown]
# * **확인**

# %%
df_dens[(df_dens['행정구역'].isin(ansim_list)) & (df_dens['year']==2020)]
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 13890  안심3동  2020      7  21450     6.10   3516.393443
# 13891  안심3동  2020      8  21443     6.10   3515.245902
# 13892  안심3동  2020      9  21388     6.10   3506.229508
# 13893  안심3동  2020     10  21379     6.10   3504.754098
# 13894  안심3동  2020     11  21380     6.10   3504.918033
# 13895  안심3동  2020     12  21337     6.10   3497.868852
# 13918  안심4동  2020      7  29515     2.53  11666.007905
# 13919  안심4동  2020      8  29515     2.53  11666.007905
# 13920  안심4동  2020      9  29453     2.53  11641.501976
# 13921  안심4동  2020     10  29409     2.53  11624.110672
# 13922  안심4동  2020     11  29367     2.53  11607.509881
# 13923  안심4동  2020     12  29277     2.53  11571.936759
# 18549   혁신동  2020      7  18779    16.42   1143.666261
# 18550   혁신동  2020      8  18845    16.42   1147.685749
# 18551   혁신동  2020      9  18859    16.42   1148.538368
# 18552   혁신동  2020     10  18846    16.42   1147.746650
# 18553   혁신동  2020     11  18821    16.42   1146.224117
# 18554   혁신동  2020     12  18863    16.42   1148.781973

# %%
df_dens[df_dens['인구밀도'] == 0]
# Out:
#       행정구역  year  month  count  면적(km²)  인구밀도
# 14913  유천동  2021      1      0     1.25   0.0
# 14914  유천동  2021      2      0     1.25   0.0
# 14915  유천동  2021      3      0     1.25   0.0
# 14916  유천동  2021      4      0     1.25   0.0
# 14917  유천동  2021      5      0     1.25   0.0
# 14918  유천동  2021      6      0     1.25   0.0
# 14919  유천동  2021      7      0     1.25   0.0
# 14920  유천동  2021      8      0     1.25   0.0
# 14921  유천동  2021      9      0     1.25   0.0
# 14922  유천동  2021     10      0     1.25   0.0

# %% [markdown]
# **4-2. 유천동 데이터 확인**
# * 로우 데이터에도 2021년 유천동의 인구수가 0이다. -> 전처리 과정은 문제가 없다.
#
# 조사
# * 2021년 11월 29일 행정동 진천동과 월성1동에서 유천동으로 분동[9]
# 출처 : https://ko.wikipedia.org/wiki/%EC%9C%A0%EC%B2%9C%EB%8F%99_(%EB%8C%80%EA%B5%AC)
#
#
# * 반면 유천동 신설로 월성1동 면적은 기존 2.57㎢에서 2.18㎢로 줄고,
# 진천동도 5.97㎢에서 5.11㎢로 줄어들게 된다.
# 출처 : http://news.imaeil.com/page/view/2021100616270719929

# %%
df_dens[df_dens['행정구역'] == '유천동']
# Out:
#       행정구역  year  month  count  면적(km²)     인구밀도
# 14913  유천동  2021      1      0     1.25      0.0
# 14914  유천동  2021      2      0     1.25      0.0
# 14915  유천동  2021      3      0     1.25      0.0
# 14916  유천동  2021      4      0     1.25      0.0
# 14917  유천동  2021      5      0     1.25      0.0
# 14918  유천동  2021      6      0     1.25      0.0
# 14919  유천동  2021      7      0     1.25      0.0
# 14920  유천동  2021      8      0     1.25      0.0
# 14921  유천동  2021      9      0     1.25      0.0
# 14922  유천동  2021     10      0     1.25      0.0
# 14923  유천동  2021     11  30194     1.25  24155.2
# 14924  유천동  2021     12  31780     1.25  25424.0
# 14925  유천동  2022      1  32710     1.25  26168.0
# 14926  유천동  2022      2  33277     1.25  26621.6
# 14927  유천동  2022      3  33443     1.25  26754.4
# 14928  유천동  2022      4  33505     1.25  26804.0

# %% [markdown]
# * **df_HI에는 유천동이 없음**

# %%
df_HI[df_HI['region'] == '유천동']
# Out:
# Empty DataFrame
# Columns: [region, year, month, HI]
# Index: []

# %% [markdown]
# * **df_HI에 유천동이 없기 때문에 df_dens에서 제거**

# %%
df_dens.drop(df_dens[(df_dens['행정구역'] == '유천동')].index, inplace=True)

df_dens[(df_dens['행정구역'] == '유천동')]
# Out:
# Empty DataFrame
# Columns: [행정구역, year, month, count, 면적(km²), 인구밀도]
# Index: []

# %% [markdown]
# **4-3. 월성1동 데이터 확인**

# %%
df_dens[df_dens['행정구역'] == '월성1동']
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 14496  월성1동  2010     10  34033     2.18  15611.467890
# 14497  월성1동  2010     11  34653     2.18  15895.871560
# 14498  월성1동  2010     12  35528     2.18  16297.247706
# 14499  월성1동  2011      1  36154     2.18  16584.403670
# 14500  월성1동  2011      2  36902     2.18  16927.522936
# ...     ...   ...    ...    ...      ...           ...
# 14630  월성1동  2021     12  37326     2.18  17122.018349
# 14631  월성1동  2022      1  37186     2.18  17057.798165
# 14632  월성1동  2022      2  37109     2.18  17022.477064
# 14633  월성1동  2022      3  37011     2.18  16977.522936
# 14634  월성1동  2022      4  36967     2.18  16957.339450
#
# [139 rows x 6 columns]

# %% [markdown]
# * **2021년 10월까지의 면적을 2.57로 변경하고 인구밀도도 재계산**

# %%
WS_filter = ((df_dens['행정구역'] == '월성1동') & (df_dens['year'] == 2021) & (df_dens['month'] < 11)) | ((df_dens['행정구역'] == '월성1동') & (df_dens['year'] < 2021))

df_dens.loc[WS_filter, '면적(km²)'] = 2.57

df_dens.loc[WS_filter, '인구밀도'] = df_dens.loc[WS_filter, 'count'] / df_dens.loc[WS_filter, '면적(km²)']

# 확인

df_dens[df_dens['행정구역'] == '월성1동']
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 14496  월성1동  2010     10  34033     2.57  13242.412451
# 14497  월성1동  2010     11  34653     2.57  13483.657588
# 14498  월성1동  2010     12  35528     2.57  13824.124514
# 14499  월성1동  2011      1  36154     2.57  14067.704280
# 14500  월성1동  2011      2  36902     2.57  14358.754864
# ...     ...   ...    ...    ...      ...           ...
# 14630  월성1동  2021     12  37326     2.18  17122.018349
# 14631  월성1동  2022      1  37186     2.18  17057.798165
# 14632  월성1동  2022      2  37109     2.18  17022.477064
# 14633  월성1동  2022      3  37011     2.18  16977.522936
# 14634  월성1동  2022      4  36967     2.18  16957.339450
#
# [139 rows x 6 columns]

# %% [markdown]
# **4-4. 진천동 데이터 확인**

# %%
df_dens[df_dens['행정구역'] == '진천동']
# Out:
#       행정구역  year  month  count  면적(km²)         인구밀도
# 16319  진천동  2010     10  52779     5.97  8840.703518
# 16320  진천동  2010     11  52775     5.97  8840.033501
# 16321  진천동  2010     12  52740     5.97  8834.170854
# 16322  진천동  2011      1  52696     5.97  8826.800670
# 16323  진천동  2011      2  52674     5.97  8823.115578
# ...    ...   ...    ...    ...      ...          ...
# 16453  진천동  2021     12  51502     5.97  8626.800670
# 16454  진천동  2022      1  51348     5.97  8601.005025
# 16455  진천동  2022      2  51254     5.97  8585.259631
# 16456  진천동  2022      3  51098     5.97  8559.128978
# 16457  진천동  2022      4  50949     5.97  8534.170854
#
# [139 rows x 6 columns]

# %% [markdown]
# * **2021년 10월 이후의 면적을 5.11로 변경하고 인구밀도도 재계산**

# %%
JC_filter = ((df_dens['행정구역'] == '진천동') & (df_dens['year'] == 2021) & (df_dens['month'] >= 11)) | ((df_dens['행정구역'] == '진천동') & (df_dens['year'] > 2021))

df_dens.loc[JC_filter, '면적(km²)'] = 5.11

df_dens.loc[JC_filter, '인구밀도'] = df_dens.loc[JC_filter, 'count'] / df_dens.loc[JC_filter, '면적(km²)']

# 확인

df_dens[df_dens['행정구역'] == '진천동']
# Out:
#       행정구역  year  month  count  면적(km²)          인구밀도
# 16319  진천동  2010     10  52779     5.97   8840.703518
# 16320  진천동  2010     11  52775     5.97   8840.033501
# 16321  진천동  2010     12  52740     5.97   8834.170854
# 16322  진천동  2011      1  52696     5.97   8826.800670
# 16323  진천동  2011      2  52674     5.97   8823.115578
# ...    ...   ...    ...    ...      ...           ...
# 16453  진천동  2021     12  51502     5.11  10078.669276
# 16454  진천동  2022      1  51348     5.11  10048.532290
# 16455  진천동  2022      2  51254     5.11  10030.136986
# 16456  진천동  2022      3  51098     5.11   9999.608611
# 16457  진천동  2022      4  50949     5.11   9970.450098
#
# [139 rows x 6 columns]

# %%
df_dens
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도
# 0       가창면  2010     10   9002   111.17     80.975083
# 1       가창면  2010     11   8969   111.17     80.678241
# 2       가창면  2010     12   8936   111.17     80.381398
# 3       가창면  2011      1   8892   111.17     79.985608
# 4       가창면  2011      2   8731   111.17     78.537375
# ...     ...   ...    ...    ...      ...           ...
# 19400  효목2동  2021     12  13167     0.72  18287.500000
# 19401  효목2동  2022      1  13121     0.72  18223.611111
# 19402  효목2동  2022      2  13098     0.72  18191.666667
# 19403  효목2동  2022      3  13070     0.72  18152.777778
# 19404  효목2동  2022      4  13043     0.72  18115.277778
#
# [19365 rows x 6 columns]

# %% [markdown]
# **5. 전처리 완료 데이터 JOIN 후 저장**

# %%
df_join = pd.merge(df_dens, df_HI, left_on=['행정구역','year','month'], right_on = ['region','year','month'], how='outer')

df_join
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도 region         HI
# 0       가창면  2010     10   9002   111.17     80.975083    가창면  14.002856
# 1       가창면  2010     11   8969   111.17     80.678241    가창면   5.548623
# 2       가창면  2010     12   8936   111.17     80.381398    가창면  -0.149288
# 3       가창면  2011      1   8892   111.17     79.985608    가창면  -4.443683
# 4       가창면  2011      2   8731   111.17     78.537375    가창면   1.583097
# ...     ...   ...    ...    ...      ...           ...    ...        ...
# 19360  효목2동  2021     12  13167     0.72  18287.500000   효목2동   2.357998
# 19361  효목2동  2022      1  13121     0.72  18223.611111   효목2동   0.478563
# 19362  효목2동  2022      2  13098     0.72  18191.666667   효목2동   1.146696
# 19363  효목2동  2022      3  13070     0.72  18152.777778   효목2동   8.569070
# 19364  효목2동  2022      4  13043     0.72  18115.277778   효목2동  15.072408
#
# [19365 rows x 8 columns]

# %% [markdown]
# * **null값 확인**

# %%
df_join[df_join['HI'].isnull()]
# Out:
# Empty DataFrame
# Columns: [행정구역, year, month, count, 면적(km²), 인구밀도, region, HI]
# Index: []

# %%
df_join[df_join['인구밀도'].isnull()]
# Out:
# Empty DataFrame
# Columns: [행정구역, year, month, count, 면적(km²), 인구밀도, region, HI]
# Index: []

# %%
df_join[df_join['행정구역'].isnull()]
# Out:
# Empty DataFrame
# Columns: [행정구역, year, month, count, 면적(km²), 인구밀도, region, HI]
# Index: []

# %%
df_join[df_join['region'].isnull()]
# Out:
# Empty DataFrame
# Columns: [행정구역, year, month, count, 면적(km²), 인구밀도, region, HI]
# Index: []

# %% [markdown]
# * **저장**

# %%
df_join.to_csv('../../output/Daegu_density+HI.csv')

# %% [markdown]
# ### 1. 기간별 인구밀도와 열지수의 상관관계 분석

# %% [markdown]
# ##### **0. 데이터 불러오기 및 설정**

# %%
# 한글 출력 오류
system_name = platform.system()
if system_name == 'Windows':
    # Windows 운영체제
    plt.rc('font', family='Malgun Gothic')
elif system_name == 'Darwin':
    # Mac OS
    plt.rc('font', family='AppleGothic')
elif system_name == 'Linux':
    # Linux
    path = '/usr/share/fonts/truetype/nanum/NanumMyeongjo.ttf'
    font_name = fm.FontProperties(fname=path, size=12)
    plt.rc('font', family=font_name)
else:
    print("Not support")

# %%
df_EDA2 = pd.read_csv('../../output/Daegu_density+HI.csv', index_col=0)

df_EDA2
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도 region         HI
# 0       가창면  2010     10   9002   111.17     80.975083    가창면  14.002856
# 1       가창면  2010     11   8969   111.17     80.678241    가창면   5.548623
# 2       가창면  2010     12   8936   111.17     80.381398    가창면  -0.149288
# 3       가창면  2011      1   8892   111.17     79.985608    가창면  -4.443683
# 4       가창면  2011      2   8731   111.17     78.537375    가창면   1.583097
# ...     ...   ...    ...    ...      ...           ...    ...        ...
# 19360  효목2동  2021     12  13167     0.72  18287.500000   효목2동   2.357998
# 19361  효목2동  2022      1  13121     0.72  18223.611111   효목2동   0.478563
# 19362  효목2동  2022      2  13098     0.72  18191.666667   효목2동   1.146696
# 19363  효목2동  2022      3  13070     0.72  18152.777778   효목2동   8.569070
# 19364  효목2동  2022      4  13043     0.72  18115.277778   효목2동  15.072408
#
# [19365 rows x 8 columns]

# %% [markdown]
# **1. 전체 기간에서의 상관관계**

# %%
EDA2_corr = df_EDA2.corr()

EDA2_corr
# Out:
#              year     month     count   면적(km²)      인구밀도        HI
# year     1.000000 -0.107872 -0.025832 -0.001451 -0.068907  0.008606
# month   -0.107872  1.000000  0.000820 -0.000023  0.001415  0.235840
# count   -0.025832  0.000820  1.000000  0.139146 -0.062834 -0.010814
# 면적(km²) -0.001451 -0.000023  0.139146  1.000000 -0.464588 -0.012767
# 인구밀도    -0.068907  0.001415 -0.062834 -0.464588  1.000000  0.005349
# HI       0.008606  0.235840 -0.010814 -0.012767  0.005349  1.000000

# %%
matplotlib.rcParams['axes.unicode_minus'] = False
sns.heatmap(EDA2_corr, cmap='viridis')
plt.show()

# 유의미한 상관관계를 관찰하기 어렵다.

# %% [markdown]
# **2. 열지수가 높은 월의 상관관계 (6, 7, 8월)**

# %% [markdown]
# * **열지수 평균 상위 3개 월 선정**

# %%
df_EDA2_by_Mean = df_EDA2.groupby(['year', 'month']).mean().reset_index()

df_EDA2_by_Mean.plot(kind = 'scatter', x='month', y='HI')
# Out:
# <AxesSubplot:xlabel='month', ylabel='HI'>

# %%
df_EDA2_high3 = df_EDA2[(df_EDA2['month'] > 5) & (df_EDA2['month'] < 10)]

df_EDA2_high3
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도 region         HI
# 8       가창면  2011      6   8537   111.17     76.792300    가창면  23.061386
# 9       가창면  2011      7   8517   111.17     76.612395    가창면  26.618988
# 10      가창면  2011      8   8502   111.17     76.477467    가창면  26.118591
# 11      가창면  2011      9   8475   111.17     76.234596    가창면  21.224170
# 20      가창면  2012      6   8379   111.17     75.371053    가창면  21.066469
# ...     ...   ...    ...    ...      ...           ...    ...        ...
# 19345  효목2동  2020      9  14555     0.72  20215.277778   효목2동  21.249131
# 19354  효목2동  2021      6  13508     0.72  18761.111111   효목2동  23.257631
# 19355  효목2동  2021      7  13412     0.72  18627.777778   효목2동  28.243597
# 19356  효목2동  2021      8  13370     0.72  18569.444444   효목2동  26.717702
# 19357  효목2동  2021      9  13287     0.72  18454.166667   효목2동  22.271067
#
# [6130 rows x 8 columns]

# %% [markdown]
# * **그래프**

# %%
df_EDA2_corr_2 = df_EDA2_high3.corr()

df_EDA2_corr_2
# Out:
#              year     month     count   면적(km²)      인구밀도        HI
# year     1.000000  0.000552 -0.023145 -0.001414 -0.067021 -0.001626
# month    0.000552  1.000000 -0.001129 -0.000188 -0.001959 -0.155281
# count   -0.023145 -0.001129  1.000000  0.138201 -0.061585 -0.037566
# 면적(km²) -0.001414 -0.000188  0.138201  1.000000 -0.464603 -0.034886
# 인구밀도    -0.067021 -0.001959 -0.061585 -0.464603  1.000000  0.015435
# HI      -0.001626 -0.155281 -0.037566 -0.034886  0.015435  1.000000

# %%
plt.figure(figsize=(14,10))
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

# matplotlib 폰트설정
plt.rc('font', family='Malgun Gothic') # For Windows
print(plt.rcParams['font.family'])

matplotlib.rcParams['axes.unicode_minus'] = False
sns.heatmap(df_EDA2_corr_2, cmap='viridis')
plt.show()

# 유의미한 상관관계를 관찰하기 어렵다.
# Out:
# ['Malgun Gothic']

# %% [markdown]
# ### 2. 최대 열지수와 최대 인구밀도의 상관관계 분석

# %% [markdown]
# * **열지수와 인구밀도 상위 100개의 값 추출**

# %%
df_EDA2_by_Max = df_EDA2.groupby(['행정구역','year', 'month']).max().reset_index()

# df_EDA2_by_Max.plot(kind = 'scatter', x='month', y='HI')

df_EDA2_by_Max
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도 region         HI
# 0       가창면  2010     10   9002   111.17     80.975083    가창면  14.002856
# 1       가창면  2010     11   8969   111.17     80.678241    가창면   5.548623
# 2       가창면  2010     12   8936   111.17     80.381398    가창면  -0.149288
# 3       가창면  2011      1   8892   111.17     79.985608    가창면  -4.443683
# 4       가창면  2011      2   8731   111.17     78.537375    가창면   1.583097
# ...     ...   ...    ...    ...      ...           ...    ...        ...
# 19360  효목2동  2021     12  13167     0.72  18287.500000   효목2동   2.357998
# 19361  효목2동  2022      1  13121     0.72  18223.611111   효목2동   0.478563
# 19362  효목2동  2022      2  13098     0.72  18191.666667   효목2동   1.146696
# 19363  효목2동  2022      3  13070     0.72  18152.777778   효목2동   8.569070
# 19364  효목2동  2022      4  13043     0.72  18115.277778   효목2동  15.072408
#
# [19365 rows x 8 columns]

# %%
df_EDA2_top =df_EDA2_by_Max.sort_values(by=['HI', '인구밀도'], ascending=False).head(100)

df_EDA2_top
# Out:
#        행정구역  year  month  count  면적(km²)          인구밀도 region         HI
# 3176    다사읍  2020      8  89687    36.66   2446.453901    다사읍  33.738278
# 18349   하빈면  2020      8   3669    36.70     99.972752    하빈면  33.738278
# 3037    논공읍  2020      8  18486    43.87    421.381354    논공읍  32.707299
# 18788   화원읍  2020      8  48338    27.68   1746.315029    화원읍  32.685176
# 14040   옥포읍  2020      8  25336    48.94    517.695137    옥포읍  32.685176
# ...     ...   ...    ...    ...      ...           ...    ...        ...
# 4844    대신동  2020      8   8097     0.52  15571.153846    대신동  32.099886
# 7207   범어1동  2020      8  16383     1.09  15030.275229   범어1동  32.099886
# 7346   범어2동  2020      8  15584     1.13  13791.150442   범어2동  32.099886
# 3732   대명2동  2020      8  11092     0.83  13363.855422   대명2동  32.099886
# 15847    중동  2020      8  11740     0.91  12901.098901     중동  32.099886
#
# [100 rows x 8 columns]

# %% [markdown]
# * **그래프**

# %%
df_EDA2_top_corr = df_EDA2_top.corr()

df_EDA2_top_corr
# Out:
#              year     month     count   면적(km²)      인구밀도        HI
# year     1.000000  1.000000  0.106368  0.027787  0.088295 -0.010721
# month    1.000000  1.000000  0.106368  0.027787  0.088295 -0.010721
# count    0.106368  0.106368  1.000000  0.472692 -0.111739  0.492188
# 면적(km²)  0.027787  0.027787  0.472692  1.000000 -0.543788  0.550879
# 인구밀도     0.088295  0.088295 -0.111739 -0.543788  1.000000 -0.351500
# HI      -0.010721 -0.010721  0.492188  0.550879 -0.351500  1.000000

# %%
plt.figure(figsize=(14,10))
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)

matplotlib.rcParams['axes.unicode_minus'] = False
sns.heatmap(df_EDA2_corr_2, cmap='viridis')
plt.show()

# %% [markdown]
# -------------------
# **그래프 관찰결과**
# * 열지수 상위 100개의 경우에는 전체 데이터보다 상관관계가 더 명확하다.
#
#
# * 면적과 열지수의 상관관계가 가장 유의미하고 다음으로 인구밀도, 인구수의 상관관계가 높다.
# 특이한 사실은 인구밀도와 열지수는 음의 상관관계를 보인다는 점이다.
# -------------------

# %% [markdown]
# ### 3. 결론

# %% [markdown]
# * 전체 데이터에서는 유의미한 상관관계를 발견할 수 없었다.
#
#
# * 전체 데이터보다 열지수 상위 100개의 경우 상관관계가 더 뚜렷하지만 유의미한 정도는 아니다.
#
#
# * 열지수 상위 100개의 경우 인구밀도와 열지수는 음의 상관관계를 보인다.
# (열지수가 높을수록 인구밀도가 낮다.)

# %% [markdown]
# **모든 월과 평균 기온이 높은 월에서 인구밀도와 열지수는 유의미한 상관관계가 없다.**
#
#
# **열지수 상위 100개의 경우 열지수가 높을수록 인구밀도가 낮은 음의 상관관계가 관찰되었다.**
#
#
# **따라서 '인구밀도가 높은 지역은 상대적으로 열지수가 높다'는 가설을 기각한다.**
